# %%
import lxml
from bs4 import BeautifulSoup
import re
from utils import *

# %%
def get_house(out = 'assembly'):
    """
    Get all data for Representatives/Senators
    
    INPUT
    out the legislative house
    
    SAVE TO FILE out.csv
    data
    
    SAVE TO FILE out_list.txt
    names of all the representatives
    
    
    OLD REGEX
        https://regex101.com/r/gMxWf4/1
        regex = r'\n(.+?), (.+?) \(([R|D]) - (.+?)\)\s+(.+|)\s+District (\d+?)\n\n' + \
            r'Details\s+(Website|)\s+Madison Office:\n\s+(.+)\s+Telephone:\n\s+(.+)\s+' + \
            r'Fax:\n\s+(.+)\s+(District Phone:\n(.+)|)\s+Email:\n(.+)\s+' + \
            r'(Voting Address:\n\s+(.+)|)\s+(Staff:\n((.|\n)+)|)'
        rep, 1 LastName 0
         2 FirstName 1 
         3 Party 2
         4 City 3
         5 Position 4
         6 District 5
         7 
         8 MadisonOffice 6
         9 Telephone 7
         10 Fax 8
         11 
         12 DistrictPhone 9
         13 Email 10
         14 
         15 VotingAddress 11
         16 
         17 Staff 12
    """

    if out not in ['assembly', 'senate']:
        warning('Input must be either "assembly" or "senate".')
        return 0
    
    # store
    house = []
    
    # Go to main list and parse html
    url = 'https://docs.legis.wisconsin.gov/2015/legislators/' + out
    text = load_txt(url)
    parser = BeautifulSoup(text, "lxml")
    legislators = parser.body.find_all('div', attrs={'class':'rounded'})
    
    # set up regex for websites
    ow = r'/2015/legislators/' + out + r'/'
    pw = r'http://legis.wisconsin.gov/' + out + '/'
    official_web = re.compile(ow)
    personal_web = re.compile(pw)
    
    # Each representative has official website, and most have personal website
    # official is your 4digit ID at the end of 
    #     http://docs.legis.wisconsin.gov/2015/legislators/OUT/
    # personal is your District/LastName at the end of
    #     http://legis.wisconsin.gov/OUT/
    off_head = 'http://docs.legis.wisconsin.gov'
    
    # once into official website with legislator details
    # set up regex
    # https://regex101.com/r/d36hI9/1
    regex = r'\n\w+? (\w+?) (\w+?)\s+((.+?)|)\n+\w+ District (\d+?) \((R|D) - (.+?)\)(\s|\S)+?Madison Office:\s+(.+?)\s+Telephone:\n\s+(.+)\s+Fax:\n\s+(.+)\s+(District Phone:\n(.+)|)\s+Email:\n(.+)\s+(Voting Address:\n\s+(.+)|)\s+Staff:\n((\s|\S)+?)\n(Current Committees\n((\s|\S)+?)|)\n\s+Biography\n((.| |\n)+)'
    regex = re.compile(regex)
    
    # each person also has feed websites with lots and lots more information
    ## author index
    # http://docs.legis.wisconsin.gov/2015/related/author_index/assembly/1362?view=section
    # http://docs.legis.wisconsin.gov/2017/related/author_index/senate/1501
    # http://docs.legis.wisconsin.gov/2015/related/author_index/senate
    ## Authored Proposals Feed
    # http://docs.legis.wisconsin.gov/feed/2015/legislators/assembly/1362?kind=authored_proposals
    # http://docs.legis.wisconsin.gov/feed/2017/legislators/senate/1501?kind=authored_proposals
    ## All Related Items Feed
    # http://docs.legis.wisconsin.gov/feed/2017/legislators/senate/1501
    # http://docs.legis.wisconsin.gov/feed/2015/legislators/assembly/1362
    ## Some of these are duplicates of the later info[1]
    
    # for each legislators
    for legis in legislators:
        # ignore class="breadcrumb rounded"
        if legis['class'][0] == 'breadcrumb': continue

        # find websites of this guy
        official, personal = None, None
        for link in legis.find_all('a'):
            tmp = link.get('href')
            if tmp:
                if official and personal: break
                tmp = link.get('href')
                if official_web.match(tmp) is not None:
                    official = off_head + tmp #tmp[-4:]
                if personal_web.match(tmp):
                    personal = tmp
        
        # go to official site and grab all other information
        if official: 
            # parse html
            text = load_txt(official)
            parser = BeautifulSoup(text, 'lxml')
            info = parser.body.find_all('div', attrs={'class':'span6'})

            if len(info) != 2:
                warn = 'This site does not have 2 <div class="span6">'
                warning(warn, 'No data was retrieved', official)
            
            # match for data
            inf = info[0].get_text()
            match = regex.search(inf)
            if not match:
                warning('No data parsed for representative. HTML below.', inf, official)
                # return BUT THIS IS BREAKING CODE
                continue
                  
            # edit data
            rep = edit_house(match)
#             # other data
#             rep.extend([official, personal])
#             # also feed websites, see above the 'for' loop for notes
            
            # save data
            house.append(rep)
        else: 
            warn = 'Website missing: official'
            warning(warn, official, legis.find_all('a'))
        
        print 'okay'
        
    print len(house)
    return house

# %%
def edit_house(match):
    """
    Reduce data for Representatives/Senators
    
    INPUT
    match the regex search matches, retrieve with match.group(i)
    
    OUTPUT
    rep, 1 LastName 0 str
         2 FirstName 1 str
         3 
         4 Position 2 str (None)
         5 District 3 short int
         6 Party 4 char
         7 City 5 str
         8 
         9 MadisonOffice 6 str
         10 Telephones 7 ?
         11 Fax 8 str
         12 
         13 DistrictPhone 9 str (None)
         14 Email 10 str
         15 
         16 VotingAddress 11 str (None)
         17 Staff 12
         18 
         19 
         20 Committees 13 list (None)
         21 
         22 Biography 14 list
    

    """
        
    def edit_house_address(address):
        """Reformat address"""
        return re.sub(r'([a-z]|\d|\.)([A-Z])', r'\1 \2', address)
    
    def edit_house_telephones(telephone):
        """Reformat Telephones"""
        return re.sub(r'(\d)\(', r'\1, (', telephone)

    def edit_house_staff(staff):
        """Reformat Staff"""
        tmp = filter(None, staff.rstrip().split('\n'))
        return [(tmp[j], tmp[j+1]) for j in xrange(0, len(tmp), 2)]
    
    
    
    # get matches
    #index = [i for i in range(0,23) if i not in [3, 8, 12, 15, 18, 19, 21]]
    index = [0, 1, 2, 4, 5, 6, 7, 9, 10, 11, 13, 14, 16, 17, 20, 22]
    rep = match.group(index)
    
    # Addresses
    # Room 113 NorthState CapitolP.O. Box 8952Madison, WI 53708
    # 10 Division St.Milton, WI 53563
    rep[9] = edit_house_address(rep[9])
    rep[16] = edit_house_address(rep[16])
    
    # Telephones
    rep[10] = edit_house_telephones(rep[10])
    
    # Staff
    rep[17] = edit_house_staff(staff)
    
    # Others! Committees and Biography
    
    return rep

# %%
x = get_house()
# Out:
# 91
